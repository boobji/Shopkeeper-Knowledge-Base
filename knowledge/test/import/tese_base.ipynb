# %% [markdown]
# ## 1.测试path使用

# %%
from pathlib import Path
pdf_path = r'/\knowledge\processor\import_process\import_temp_dir\万用表RS-12的使用.pdf'
path = Path(pdf_path)
path.stem
# Out:
# '万用表RS-12的使用'
